# %% [markdown]
# # Create LESCO Time-Series dataset with Image Augmentation
#
# Download the dataset at: [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.5756387.svg)](https://doi.org/10.5281/zenodo.5756387)

# %%
import warnings
warnings.filterwarnings('ignore')
from IPython.display import clear_output

import numpy as np
import cv2 as cv
import mediapipe as mp
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

import pandas as pd
import os
import csv

# code with all the needed functionality
import lesco as lsc

mp_hands = mp.solutions.hands

# %%
# read all paths and extract classes from folder names.
root = r"C:\Users\XPC\Desktop\LESCO-dataset"

classes_ = []
files_ = []

for path, subdirs, files in os.walk(root):
    for name in files:
        class_name = os.path.basename(path)
        file_path = path + '\\' + name
        classes_.append(class_name)
        files_.append(file_path)
        
print(len(files_), "video files detected")
# Out:
# 117 video files detected

# %% [markdown]
# # Process All Files with Augmentation
# this might take a while, go for coffee...

# %%
videos = []
videos_labels = []

total = len(files_)
count = 1

tsne = TruncatedSVD(n_components=1) 

for file_, class_ in zip(files_, classes_):
    
    try:
        print("processing...", class_)
        # process videos with augmentation
        v1 = lsc.process_video(file_, tsne, False, False, 0) # normal
        v2 = lsc.process_video(file_, tsne, True, False, 0) # flipped
        v3 = lsc.process_video(file_, tsne, False, True, 5) # normal with rotation +5
        v4 = lsc.process_video(file_, tsne, False, True, -5) # normal with rotation -5
        v5 = lsc.process_video(file_, tsne, True, True, 5) # flipped with rotaion +5
        v6 = lsc.process_video(file_, tsne, True, True, -5) # flipped with rotation -5


        # add to tensor
        videos.append(v1)
        videos.append(v2)
        videos.append(v3)
        videos.append(v4)
        videos.append(v5)
        videos.append(v6)

        # create labeled list
        videos_labels.append(class_)
        videos_labels.append(class_)
        videos_labels.append(class_)
        videos_labels.append(class_)
        videos_labels.append(class_)
        videos_labels.append(class_)

        print("completed", round((count/total) * 100, 2), "%")
        print("examples created", len(videos), "\n")

    except:
        print("Error on", file_)

    count = count + 1


    if (count % 10 == 0):
        clear_output(wait=True)
    
    
print("All Videos Completed. Total Samples Created", len(videos))
# Out:
# processing... violento
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\violento\violento_2.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# completed 94.02 %
# examples created 660
#
# processing... violento
# frames processed 49
# frames processed 49
# frames processed 49
# frames processed 49
# frames processed 49
# frames processed 49
# completed 94.87 %
# examples created 666
#
# processing... vomitar
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# completed 95.73 %
# examples created 672
#
# processing... vomitar
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# frames processed 53
# completed 96.58 %
# examples created 678
#
# processing... vomitar
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# frames processed 0
# error processing video C:\Users\XPC\Desktop\LESCO-dataset\vomitar\vomitar_3.mp4 Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# completed 97.44 %
# examples created 684
#
# processing... yo
# frames processed 36
# frames processed 36
# frames processed 36
# frames processed 36
# frames processed 36
# frames processed 36
# completed 98.29 %
# examples created 690
#
# processing... yo
# frames processed 16
# frames processed 16
# frames processed 16
# frames processed 16
# frames processed 16
# frames processed 16
# completed 99.15 %
# examples created 696
#
# processing... yo
# frames processed 26
# frames processed 26
# frames processed 26
# frames processed 26
# frames processed 26
# frames processed 26
# completed 100.0 %
# examples created 702
#
# All Videos Completed. Total Samples Created 702

# %%
# save dataset to csv.
# one csv for the videos other for the labels.

with open("videos_svd.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(map(lambda x: [x], videos))
    #writer.writerows(videos)

with open("labels_svd.csv", "w", newline="") as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(videos_labels)
